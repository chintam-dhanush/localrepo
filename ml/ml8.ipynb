# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
# 1. Load MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
# 2. Normalize data (0–255 → 0–1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# 3. Build ANN model
model = models.Sequential([
layers.Flatten(input_shape=(28, 28)), # Input layer
layers.Dense(64, activation='relu'), # Hidden layer
layers.Dense(10, activation='softmax') # Output layer
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 4. Compile (defines backpropagation settings)
model.compile(
optimizer='adam', # Gradient descent
loss='sparse_categorical_crossentropy', # Loss function
metrics=['accuracy']
)

# %%
# 5. Train model (backpropagation )
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9164 - loss: 0.2982
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9586 - loss: 0.1420
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9694 - loss: 0.1036
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9751 - loss: 0.0814
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9795 - loss: 0.0672

# %%
# 6. Test model
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0830
# Test Accuracy: 0.9728000164031982
